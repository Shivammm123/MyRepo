# %%
from flyanalysis.braidz import read_braidz
from flyanalysis.plotting import plot_trajectory
from flyanalysis.plotting import plot_mean_and_std
from flyanalysis.filtering import filter_by_velocity
from flyanalysis.trajectory import get_angular_velocity
from flyanalysis.filtering import filter_by_distance

# %%
df, csvs = read_braidz("C:/Users/pandey/Desktop/Braidz Files/20240729_114735.braidz")
# Out:
# Reading C:/Users/pandey/Desktop/Braidz Files/20240729_114735.braidz using pyarrow

# %%
df[df.obj_id == 26]
# Out:
#    obj_id  frame     timestamp         x         y         z      xvel  \
# 4      26  32712  1.722246e+09  0.170895 -0.146087  0.154156 -2.101181
# 5      26  32713  1.722246e+09  0.149883 -0.135435  0.191749 -2.101181
# 6      26  32714  1.722246e+09  0.128872 -0.124783  0.229343 -2.101181
# 7      26  32715  1.722246e+09  0.106658 -0.117260  0.264051 -2.146731
#
#        yvel      zvel           P00           P01           P02           P11  \
# 4  1.065188  3.759344  5.498475e-08 -3.453055e-09 -1.925235e-08  9.534390e-08
# 5  1.065188  3.759344  3.310300e-07 -1.171309e-08 -9.566614e-08  4.954013e-07
# 6  1.065188  3.759344  1.072637e-06 -2.271625e-08 -2.480607e-07  1.447707e-06
# 7  0.962124  3.675651  2.113200e-06 -7.171683e-07 -1.594946e-06  4.581262e-07
#
#             P12           P22       P33       P44       P55
# 4  8.046118e-08  2.238362e-07  0.001328  0.001761  0.003927
# 5  3.383344e-07  1.096981e-06  0.002328  0.002761  0.004927
# ...

# %%
plot_trajectory(df[df.obj_id == 26])
# Out:
# <Axes: >

# %%
plot_trajectory(df[df.obj_id == 26])
# Out:
# <Axes: >

# %%
plot_mean_and_std(df)
# Out:
# <Axes: >

# %%
get_angular_velocity(df)
# Out:
# array([   19.98477538,     9.99238769,  -115.88596768, ...,
#         -573.33675733, -1604.21099709,  -413.05500241])

# %%
filter_by_distance(df)
# Out:
# []

# %%
filter_by_velocity(df)
# Out:
# [25,
#  26,
#  29,
#  30,
#  32,
#  33,
#  34,
#  35,
#  37,
#  43,
#  44,
#  48,
#  53,
#  56,
#  61,
#  63,
#  68,
#  74,
#  78,
#  83,
#  84,
#  85,
#  86,
#  88,
#  89,
#  91,
#  97,
#  99,
#  101,
#  104,
#  107,
#  108,
#  111,
#  115,
#  120,
#  122,
#  123,
#  126,
#  127,
#  130,
#  132,
#  135,
#  137,
#  138,
#  144,
#  145,
#  149,
#  150,
#  152,
#  154,
#  157,
#  158,
#  161,
#  163,
#  164,
#  167,
#  169,
#  170,
#  171,
#  174,
#  178,
#  180,
#  183,
#  184,
#  186,
#  187,
#  188,
#  192,
#  194,
#  195,
#  197,
#  199,
#  200,
#  201,
#  204,
#  207,
#  210,
#  212,
#  214,
#  219,
#  220,
#  224,
#  225,
#  226,
#  228,
#  230,
#  232,
#  235,
#  282,
#  3732,
#  5360,
#  5384,
#  5385,
#  6575,
#  6594,
#  6611,
#  6727,
#  6730,
#  6783,
#  6880,
#  6890,
#  6897,
#  6912,
#  6946,
#  6972,
#  7205,
#  7233,
#  7239,
#  7242,
#  7253,
#  7258,
#  7261,
#  7265,
#  7267,
#  7268,
#  7270,
#  7273,
#  7276,
#  7277,
#  7278,
#  7279,
#  7280,
#  7284,
#  7288,
# ...

# %%
filter_by_velocity(df)
# Out:
# [25,
#  26,
#  29,
#  30,
#  32,
#  33,
#  34,
#  35,
#  37,
#  43,
#  44,
#  48,
#  53,
#  56,
#  61,
#  63,
#  68,
#  74,
#  78,
#  83,
#  84,
#  85,
#  86,
#  88,
#  89,
#  91,
#  97,
#  99,
#  101,
#  104,
#  107,
#  108,
#  111,
#  115,
#  120,
#  122,
#  123,
#  126,
#  127,
#  130,
#  132,
#  135,
#  137,
#  138,
#  144,
#  145,
#  149,
#  150,
#  152,
#  154,
#  157,
#  158,
#  161,
#  163,
#  164,
#  167,
#  169,
#  170,
#  171,
#  174,
#  178,
#  180,
#  183,
#  184,
#  186,
#  187,
#  188,
#  192,
#  194,
#  195,
#  197,
#  199,
#  200,
#  201,
#  204,
#  207,
#  210,
#  212,
#  214,
#  219,
#  220,
#  224,
#  225,
#  226,
#  228,
#  230,
#  232,
#  235,
#  282,
#  3732,
#  5360,
#  5384,
#  5385,
#  6575,
#  6594,
#  6611,
#  6727,
#  6730,
#  6783,
#  6880,
#  6890,
#  6897,
#  6912,
#  6946,
#  6972,
#  7205,
#  7233,
#  7239,
#  7242,
#  7253,
#  7258,
#  7261,
#  7265,
#  7267,
#  7268,
#  7270,
#  7273,
#  7276,
#  7277,
#  7278,
#  7279,
#  7280,
#  7284,
#  7288,
# ...

# %%
filter_by_velocity(df[df.obj_id == 26])
# Out:
# [26]

# %%
 plot_mean_and_std(df[df.obj_id == 25])
# Out:
# <Axes: >

# %%
df, csvs = read_braidz("C:/Users/pandey/Desktop/Braidz Files/20240729_114735.braidz")
# Out:
# Reading C:/Users/pandey/Desktop/Braidz Files/20240729_114735.braidz using pyarrow

# %%
plot_trajectory(df)
# Out:
# <Axes: >

# %%
get_angular_velocity(df[df.obj_id == 26])
# Out:
# array([  0.        ,   0.        , 137.07955616, 274.15911232])

# %%
result = get_angular_velocity(df[df.obj_id == 26])

# %%
print(result)
# Out:
# [  0.           0.         137.07955616 274.15911232]

# %%
result_list = list(result)
print(result_list)
# Out:
# [0.0, 0.0, 137.07955616053664, 274.1591123210733]
