# %%
from flyanalysis.braidz import read_braidz

# %%
df, csvs = read_braidz("C:/Users/pandey/Desktop/Braidz Files/20240729_114735.braidz")
# Out:
# Reading C:/Users/pandey/Desktop/Braidz Files/20240729_114735.braidz using pyarrow

# %%
print (df)
# Out:
#         obj_id    frame     timestamp         x         y         z      xvel  \
# 0           25    32709  1.722246e+09  0.149475 -0.137659  0.182970 -2.091721
# 1           25    32710  1.722246e+09  0.128872 -0.129018  0.216767 -2.074794
# 2           25    32711  1.722246e+09  0.108125 -0.120316  0.249578 -2.074794
# 3           25    32712  1.722246e+09  0.089179 -0.109957  0.285631 -1.990824
# 4           26    32712  1.722246e+09  0.170895 -0.146087  0.154156 -2.101181
# ...        ...      ...           ...       ...       ...       ...       ...
# 918322   55508  8535073  1.722332e+09  0.152314  0.002393  0.000446 -0.012294
# 918323   55511  8694577  1.722333e+09  0.145806 -0.046440  0.002116  0.002778
# 918324   55511  8694578  1.722333e+09  0.145955 -0.046666  0.002133  0.010944
# 918325   55511  8694579  1.722333e+09  0.145964 -0.047445  0.001000  0.003030
# 918326   55511  8694580  1.722333e+09  0.145920 -0.048251 -0.000683 -0.000609
#
# ...

# %%
def plot_trajectory(df: pd.DataFrame, ax: plt.Axes = None, **kwargs):
# Out:
#   Cell In[2], line 1
#     def plot_trajectory(df: pd.DataFrame, ax: plt.Axes = None, **kwargs):
#                                                                          ^
# SyntaxError: incomplete input
